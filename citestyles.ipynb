# %% [markdown]
# # Citation Styles
# ***
# ### Citation Styles Commonly Used in Arts and Humanities
# ```{raw} html
# <p><span style="font-size:14px;"><strong>Citation style</strong> refers to specific rules and guidelines for documenting sources in academic writing.&nbsp;<br />
# Your instructors may specify citation style for specific assignments or courses.</span></p>
#
# <div style="background:#eeeeee;border:1px solid #cccccc;padding:5px 10px;">
# <ul>
# 	<li><span style="font-size:14px;">Citation Styles (e.g. APA, MLA, or Chicago, etc.)&nbsp;have unique formats for citing various sources.&nbsp;</span></li>
# 	<li><span style="font-size:14px;">Each citation style provides guidelines on how to format citations for various sources.&nbsp;</span></li>
# 	<li><span style="font-size:14px;">Each citation style has its own specific formatting guidelines (e.g. hanging indent, line spacing, margin, etc.).</span></li>
# 	<li><span style="font-size:14px;">Different information formats require different citation formats.</span></li>
# 	<li><span style="font-size:14px;">Stick to one citation style and use it&nbsp;consistently throughout your work. This means that all your citations, both in-text and in the reference list or bibliography, should follow the same style guideline.&nbsp;</span></li>
# </ul>
# </div>
# ```
# ***

# %% [markdown]
# ## Citation Styles Guidelines
#
# ::::{tab-set}
# :::{tab-item} APA 7th
# ```{raw} html
# <div style="overflow: hidden;">
#   <img src="https://apastyle.apa.org/Content/Images/megamenu/images@2x/3D-manual-products-menu.png" height="130" width="90" alt="image" style="float: left; margin-right: 10px;">
#   <div>
#     <a href="http://lib.hkapa.edu/bib/991002046726504326">Publication manual of the American Psychological Association : the official guide to APA style</a><br>
#     Author: American Psychological Association<br>
#     Call Number: BF76.7 .P83 2020<br>
#     Location: Academy Library
#   </div>
# </div>
# ```
# ##### **Citation Examples**
# ```{admonition} Example 1: Book
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGGksu9nCM/JCGOL4--JrR-BrYv7yRP2A/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
#
# ```{admonition} Example 2: Journal Article
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGGk1lTnSM/5xf8MpqV3AhDK3HvIgCA7g/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
# ```{admonition} Example 3: Webpage
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGYUFwY35M/RUvz_zfg4-E_rw1NdYznYw/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
# ```{admonition} Example 4: Online Video
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGYTWGt-BA/ZbITQVfzQjUmVgyH3Sm_Xw/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
# ```{admonition} To Learn More
# :class: seealso
# [APA Style- Reference Examples](https://apastyle.apa.org/style-grammar-guidelines/references/examples#textual-works)\
# [Basics of APA Style- Academic Writer](https://academicwriter-apa-org.libproxy.hkapa.edu/learndisplay/TUT-11)
# ```
# :::
#
# :::{tab-item} Chicago 17th
# ```{raw} html
# <div style="overflow: hidden;">
#   <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRARjLTvpZs6Ln26HCj4xyX2bNKO3xH9lPTEmYlTuju-Q&s" height="130" width="90" alt="image" style="float: left; margin-right: 10px;">
#   <div>
#     <a href="http://lib.hkapa.edu/bib/991001490699704326">A manual for writers of research papers, theses, and dissertations : Chicago Style for students and researchers</a><br>
#     Author: Turabian, Kate L.<br>
#     Call Number: LB2369 .T8 2018<br>
#     Location: Academy Library
#   </div>
# </div>
# ```
# ##### **Citation Examples**
# ```{admonition} Example 1: Book
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGGk-zPx2E/0wlRuhnXAaTklSAE3BG1vA/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
#
# ```{admonition} Example 2: Journal Article
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGGk4JDzEk/AtbIje1yuDhXBUHtJiB4qQ/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
#
# ```{admonition} Example 3: Webpage
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGYUec9E0g/xgGyPpXGMpZ8CHGGk-GdmA/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
# ```{admonition} Example 4: Online Video
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGYUR_z77o/N0KWsEs1TmpO2U6eSn-gcA/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
# ```{admonition} To Learn More
# :class: seealso
# [Chicago-Style Citation Quick Guide](https://www.chicagomanualofstyle.org/tools_citationguide.html)\
# [The Chicago Manual of Style Online - Resources for Students](https://www.chicagomanualofstyle.org/help-tools/Resources-for-Students.html)
# ```
# :::
#
# :::{tab-item} MLA 9th
# ```{raw} html
# <div style="overflow: hidden;">
#   <img src="https://libapps-au.s3-ap-southeast-2.amazonaws.com/accounts/204488/images/51EL5InYSHS.jpg" height="130" width="90" alt="image" style="float: left; margin-right: 10px;">
#   <div>
#     <a href="http://lib.hkapa.edu/bib/991002192977904326">MLA handbook</a><br>
#     Author: The Modern Language Association of America<br>
#     Call Number: LB2369 .G53 2021<br>
#     Location: Academy Library
#   </div>
# </div>
# ```
# ##### **Citation Examples**
# ```{admonition} Example 1: Book
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGGk3Knkp8/GTipPEot-gFhxI2MmBDPwg/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
#
# ```{admonition} Example 2: Journal Article
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGGlXLFMUI/nNya5uDKAdcgBrlyQphw3Q/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
#
# ```{admonition} Example 3: Webpage
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGYY_wWLdU/hEfVrkNwifXfw2-0FiSj1w/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
# ```{admonition} Example 4: Online Video
# :class: tip
# ```{raw} html
# <div style="position: relative; width: 100%; height: 0; padding-top: 56.2500%;
#  padding-bottom: 0; box-shadow: 0 2px 8px 0 rgba(63,69,81,0.16); margin-top: 1.6em; margin-bottom: 0.9em; overflow: hidden;
#  border-radius: 8px; will-change: transform;">
#   <iframe loading="lazy" style="position: absolute; width: 100%; height: 100%; top: 0; left: 0; border: none; padding: 0;margin: 0;"
#     src="https://www.canva.com/design/DAGYY5Th6NI/g7Z6bJox7JjZgO8wzOXOlA/view?embed" allowfullscreen="allowfullscreen" allow="fullscreen">
#   </iframe>
# </div>
# ```
# ```{admonition} To Learn More
# :class: seealso
# [MLA Style Center](https://style.mla.org/)\
# [Purdue OWL - MLA Formatting and Style Guide](https://owl.purdue.edu/owl/research_and_citation/mla_style/mla_formatting_and_style_guide/index.html)
# ```
# :::
# ::::
